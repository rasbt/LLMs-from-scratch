# %%
# !git clone https://github.com/shaharprojs/LLMs-from-scratch-sd.git
# %cd LLMs-from-scratch-sd
# !git checkout feature/tool-calling-experiment
# Out:
# Cloning into 'LLMs-from-scratch-sd'...
# remote: Enumerating objects: 6980, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 6980 (delta 19), reused 24 (delta 8), pack-reused 6934 (from 3)
# Receiving objects: 100% (6980/6980), 15.17 MiB | 19.11 MiB/s, done.
# Resolving deltas: 100% (4367/4367), done.
# /content/LLMs-from-scratch-sd
# Branch 'feature/tool-calling-experiment' set up to track remote branch 'feature/tool-calling-experiment' from 'origin'.
# Switched to a new branch 'feature/tool-calling-experiment'

# %%
# %cd /content/LLMs-from-scratch-sd
# !python tool_calling_experiment/train_colab.py --batch_size 3 --max_length 1024
# Out:
# /content/LLMs-from-scratch-sd
# 2026-02-15 13:18:34.829825: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771161514.851109    5469 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771161514.858145    5469 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771161514.876062    5469 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %cd /content/LLMs-from-scratch-sd
# !python tool_calling_experiment/inference_colab.py
# Out:
# /content/LLMs-from-scratch-sd
# Loading model from tool_llm.pth with size 124M...
#
# Model loaded. Enter an instruction (or 'q' to quit).
#
# User: write a function that prints the sum of three numbers
# Generating code................................................................... Done.
#
# [Generated Code]
# def sum_three_numbers(numbers):
#     sum = 0
#     for num in numbers:
#         if num % 2 != 0:
#             sum += num
#     return sum
#
#
# Detected function: sum_three_numbers
# Execute? (y/n, 'e' to edit/append, 'c' to call print(sum_three_numbers())): e
# Enter code to append: print(sum_three_numbers([1,9,23])
# Executing:
# def sum_three_numbers(numbers):
#     sum = 0
#     for num in numbers:
#         if num % 2 != 0:
#             sum += num
#     return sum
#
# print(sum_three_numbers([1,9,23])
#
# [Execution Output]
# Error executing code: '(' was never closed (<string>, line 8)
#
# User:  write a function that prints the sum of three number
# ...
